# %%
import kashgari
from kashgari.embeddings import NumericFeaturesEmbedding, StackedEmbedding, BERTEmbedding
import pandas as pd
from tensorflow.python import keras
from kashgari.callbacks import EvalCallBack
import logging
logging.basicConfig(level='DEBUG')

# %%
from kashgari.tasks.labeling import BiLSTM_Model
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
TRAIN_CSV = '/Users/ishitagupta/Desktop/kashgari_data_train.csv'
train_df = pd.read_csv(TRAIN_CSV)
train_df.head()
# Out:
#                                                text1  \
# 0  We did not consider it necessary at Commission...
# 1  My second point, Commissioner, regards applica...
# 2  To this we must add the water pollution proble...
# 3  The directive concerning end-of-life vehicles ...
# 4  Information Centers for Europe, which already ...
#
#                                                text2  feature1  feature2  \
# 0  We have not found it necessary at Commission l...       724       619
# 1  My second point, Commissioner, is the applicat...       778       625
# 2  To this must be added the water pollution prob...       570       332
# 3  The End-of-Life Vehicles Directive will serve ...       613       418
# 4  Information Centers for Europe, already playin...       930       858
#
#    feature3  label
# 0       603      1
# 1       429      0
# 2       178      0
# 3       368      0
# 4       816      1

# %%
DEV_CSV = '/Users/ishitagupta/Desktop/kashgari_data_dev.csv'
dev_df = pd.read_csv(DEV_CSV)
dev_df.head()
# Out:
#                                                text1  \
# 0  Madam, the question you are asking is of utmos...
# 1  I am therefore able to say that Felix and Char...
# 2  These measures do, in fact, entail a certain n...
# 3  As others have said before me, however, our pa...
# 4  The objectives of LIFE: this must have as its ...
#
#                                                text2  feature1  feature2  \
# 0  Madam, the question you are asking is of utmos...      1000      1000
# 1  I can say that Felix and Charles-Louis of Habs...       799       747
# 2  In reality, these measures imply some degree o...       427       111
# 3  As others have already said, our partners have...       550       349
# 4  The objectives of LIFE: the main objective of ...       838       750
#
#    feature3  label
# 0      1000      1
# 1       741      1
# 2        39      0
# 3       218      0
# 4       658      0

# %%
#SEQUENCE LENGTH 
SEQUENCE_LEN = 30

# %%
#BERT MODEL 

bert_model_path= '/Users/ishitagupta/bert/uncased_L-12_H-768_A-12'
bert_embedding = BERTEmbedding(bert_model_path,
                               task=kashgari.LABELING,
                               sequence_length=SEQUENCE_LEN)

tokenizer = bert_embedding.tokenizer
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:root:seq_len: 30

# %%
#CUSTOM NUMERICAL FEATURES embedding definition , feature count is maximum allowed value of feature

feature1_embedding = NumericFeaturesEmbedding(feature_count=1000,
                                                feature_name='feature1',
                                                sequence_length=SEQUENCE_LEN)

feature2_embedding = NumericFeaturesEmbedding(feature_count=1000,
                                                feature_name='feature2',
                                                sequence_length=SEQUENCE_LEN)

feature3_embedding = NumericFeaturesEmbedding(feature_count=1000,
                                                feature_name='feature3',
                                                sequence_length=SEQUENCE_LEN)

# %%
# forming the stack embedding structure
# first one must be the text embedding
stack_embedding = StackedEmbedding([
    bert_embedding,
    feature1_embedding,
    feature2_embedding,
    feature3_embedding
])
# Out:
# [<tf.Tensor 'Input-Token:0' shape=(?, 30) dtype=float32>, <tf.Tensor 'Input-Segment:0' shape=(?, 30) dtype=float32>]
# [<tf.Tensor 'Input-Token:0' shape=(?, 30) dtype=float32>, <tf.Tensor 'Input-Segment:0' shape=(?, 30) dtype=float32>]
# Tensor("input_feature1_1:0", shape=(?, 30), dtype=float32)
# [<tf.Tensor 'input_feature1_1:0' shape=(?, 30) dtype=float32>]
# Tensor("input_feature2_1:0", shape=(?, 30), dtype=float32)
# [<tf.Tensor 'input_feature2_1:0' shape=(?, 30) dtype=float32>]
# Tensor("input_feature3_1:0", shape=(?, 30), dtype=float32)
# [<tf.Tensor 'input_feature3_1:0' shape=(?, 30) dtype=float32>]

# %%
# BERT TOKENIZER for train set
sentences_tokenized_train = []
i=0
for sentence in train_df['text1'].values: 
    #print(sentence)
    #print(train_df['text2'].values[i])
    sentence_tokenized_1 = tokenizer.tokenize(sentence)
    sentence_tokenized_2 = tokenizer.tokenize(train_df['text2'].values[i])
    sentence_tokenized = sentence_tokenized_1[:-1] + ['[SEP]']+ sentence_tokenized_2[1:]
    sentences_tokenized_train.append(sentence_tokenized)
    i += 1
    #print(sentence_tokenized)
    
# BERT TOKENIZER for dev set
sentences_tokenized_dev = []
i=0
for sentence in dev_df['text1'].values: 
    #print(sentence)
    #print(train_df['text2'].values[i])
    sentence_tokenized_1 = tokenizer.tokenize(sentence)
    sentence_tokenized_2 = tokenizer.tokenize(dev_df['text2'].values[i])
    sentence_tokenized = sentence_tokenized_1[:-1] + ['[SEP]']+ sentence_tokenized_2[1:]
    sentences_tokenized_dev.append(sentence_tokenized)
    i += 1
    #print(sentence_tokenized)
    
    
"""
The sentences will become tokenized into:
[
    ['[CLS]', 'jim', 'henson', 'was', 'a', 'puppet', '##eer', '.', '[SEP]'],
    ['[CLS]', 'this', 'here', "'", 's', 'an', 'example', 'of', 'using', 'the', 'bert', 'token', '##izer', '.', '[SEP]'],
    ['[CLS]', 'why', 'did', 'the', 'chicken', 'cross', 'the', 'road', '?', '[SEP]']
]
"""
#print(sentences_tokenized)
# Our tokenizer already added the BOS([CLS]) and EOS([SEP]) token
# so we need to disable the default add_bos_eos setting.
bert_embedding.processor.add_bos_eos = False

# %%
#converting data into a list format 
#TRAIN set
tokenized_text_list_train = sentences_tokenized_train
feature1_list_train = [list(train_df['feature1'])]*30
feature2_list_train = [list(train_df['feature2'])]*30
feature3_list_train = [list(train_df['feature3'])]*30
label_list_train = [list(train_df['label'])]

#DEV set 
tokenized_text_list_dev = sentences_tokenized_dev
feature1_list_dev = [list(dev_df['feature1'])]*30
feature2_list_dev = [list(dev_df['feature2'])]*30
feature3_list_dev = [list(dev_df['feature3'])]*30
label_list_dev = [list(dev_df['label'])]

#print(tokenized_text_list)

# %%
#compiling features together 

train_x = (tokenized_text_list_train, feature1_list_train, feature2_list_train, feature3_list_train)
train_y = label_list_train
stack_embedding.analyze_corpus(train_x, train_y)

dev_x = (tokenized_text_list_dev, feature1_list_dev, feature2_list_dev, feature3_list_dev)
dev_y = label_list_dev
stack_embedding.analyze_corpus(dev_x, dev_y)

print(train_x)
# Out:
# ([['[CLS]', 'we', 'did', 'not', 'consider', 'it', 'necessary', 'at', 'commission', '.', '.', '.', '[SEP]', 'we', 'have', 'not', 'found', 'it', 'necessary', 'at', 'commission', 'l', '.', '.', '.', '[SEP]'], ['[CLS]', 'my', 'second', 'point', ',', 'commissioner', ',', 'regards', 'app', '##lica', '.', '.', '.', '[SEP]', 'my', 'second', 'point', ',', 'commissioner', ',', 'is', 'the', 'app', '##lica', '##t', '.', '.', '.', '[SEP]'], ['[CLS]', 'to', 'this', 'we', 'must', 'add', 'the', 'water', 'pollution', 'pro', '##ble', '.', '.', '.', '[SEP]', 'to', 'this', 'must', 'be', 'added', 'the', 'water', 'pollution', 'pro', '##b', '.', '.', '.', '[SEP]'], ['[CLS]', 'the', 'directive', 'concerning', 'end', '-', 'of', '-', 'life', 'vehicles', '.', '.', '.', '[SEP]', 'the', 'end', '-', 'of', '-', 'life', 'vehicles', 'directive', 'will', 'serve', '.', '.', '.', '[SEP]'], ['[CLS]', 'information', 'centers', 'for', 'europe', ',', 'which', 'already', '.', '.', '.', '[SEP]', 'information', 'centers', 'for', 'europe', ',', 'already', 'play', '##in', '.', '.', '.', '[SEP]']], [[724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930], [724, 778, 570, 613, 930]], [[619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858], [619, 625, 332, 418, 858]], [[603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816], [603, 429, 178, 368, 816]])

# %%
# Now we can embed with this stacked embedding layer
print(stack_embedding.embed(train_x))
# Out:
# [[[-4.19380546e-01 -1.04513593e-01 -1.08738446e+00 ... -2.26973649e-02
#     3.14053334e-02  3.46138738e-02]
#   [ 2.23932222e-01 -1.54713392e-01 -1.15244555e+00 ...  1.52859725e-02
#     8.47898424e-04 -3.61638293e-02]
#   [ 1.08116293e+00  2.14800715e-01 -5.44946551e-01 ... -3.09095979e-02
#    -2.66982242e-03 -1.09117106e-03]
#   ...
#   [-2.62100250e-01  3.01898569e-01 -9.46173906e-01 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [ 9.97824848e-01  1.23400055e-01  2.53324658e-02 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-4.60988432e-01  8.20694491e-02 -1.01473665e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]]
#
#  [[-7.41079688e-01 -2.34946102e-01 -8.86214852e-01 ... -2.26973649e-02
#     3.14053334e-02  3.46138738e-02]
#   [ 9.31632519e-02  1.34138197e-01 -1.52067676e-01 ...  1.52859725e-02
#     8.47898424e-04 -3.61638293e-02]
#   [ 7.50979781e-01 -7.99746394e-01 -4.83724684e-01 ... -3.09095979e-02
#    -2.66982242e-03 -1.09117106e-03]
#   ...
#   [-1.85265017e+00 -8.95578921e-01 -1.15213978e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-2.95974314e-02  1.90291926e-02  2.63205022e-02 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-8.27405632e-01 -2.16697268e-02  2.01352924e-01 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]]
#
#  [[-9.44451153e-01 -1.98272377e-01 -1.19763267e+00 ... -2.26973649e-02
#     3.14053334e-02  3.46138738e-02]
#   [-1.11217737e+00  7.79136181e-01 -8.88915509e-02 ...  1.52859725e-02
#     8.47898424e-04 -3.61638293e-02]
#   [-4.73450929e-01  1.82221413e-01 -1.38340071e-02 ... -3.09095979e-02
#    -2.66982242e-03 -1.09117106e-03]
#   ...
#   [-1.96335280e+00 -8.56796086e-01 -1.21690965e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-1.43488571e-02  8.30917805e-03  1.62196383e-02 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-3.91098320e-01  1.96410954e-01 -2.22152263e-01 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]]
#
#  [[-6.81422532e-01 -2.62895197e-01 -8.35001111e-01 ... -2.26973649e-02
#     3.14053334e-02  3.46138738e-02]
#   [-4.11046773e-01 -7.44881988e-01  1.06531918e-01 ...  1.52859725e-02
#     8.47898424e-04 -3.61638293e-02]
#   [ 8.78613770e-01 -3.80575001e-01  8.58838484e-03 ... -3.09095979e-02
#    -2.66982242e-03 -1.09117106e-03]
#   ...
#   [ 2.67935917e-03  7.19805062e-03  3.56573984e-02 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-3.52914333e-01  4.72623706e-02  1.06756473e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-7.76231527e-01  6.08233139e-02  9.82212305e-01 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]]
#
#  [[-6.48123324e-01 -2.39624351e-01 -6.83400273e-01 ... -2.26973649e-02
#     3.14053334e-02  3.46138738e-02]
#   [-4.02682751e-01  1.87654674e-01  6.99496746e-01 ...  1.52859725e-02
#     8.47898424e-04 -3.61638293e-02]
#   [-5.72691917e-01  3.24584872e-01  1.00047886e+00 ... -3.09095979e-02
#    -2.66982242e-03 -1.09117106e-03]
#   ...
#   [-3.38447273e-01  3.12485933e-01  1.02929842e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [-2.57120728e-02  1.76627368e-01  1.12464881e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]
#   [ 9.08875108e-01 -2.84772247e-01  1.68194985e+00 ... -4.64519635e-02
#     1.36974938e-02 -1.79936998e-02]]]

# %%
# We can build any labeling model with this embedding


model = BiLSTM_Model(embedding=stack_embedding)


model.fit(train_x, train_y, dev_x, dev_y)

# Evaluate the model
#model.evaluate(test_x, test_y)

# Model data will save to `saved_ner_model` folder
model.save('/Users/ishitagupta/Kashgari/model_output_4')


#print(model.predict(x))
#print(model.predict_entities(x))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        (None, 30)           0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      (None, 30)           0
# __________________________________________________________________________________________________
# Embedding-Token (TokenEmbedding [(None, 30, 768), (3 23440896    Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, 30, 768)      1536        Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, 30, 768)      0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, 30, 768)      23040       Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Dropout (Dropout)     (None, 30, 768)      0           Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, 30, 768)      1536        Embedding-Dropout[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 30, 768)      2362368     Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-1-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 30, 768)      0           Embedding-Norm[0][0]
#                                                                  Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-1-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-1-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-1-MultiHeadSelfAttention-
#                                                                  Encoder-1-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-1-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-1-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-1-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-2-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-1-FeedForward-Norm[0][0]
#                                                                  Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-2-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-2-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-2-MultiHeadSelfAttention-
#                                                                  Encoder-2-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-2-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-2-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-2-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-3-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-2-FeedForward-Norm[0][0]
#                                                                  Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-3-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-3-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-3-MultiHeadSelfAttention-
#                                                                  Encoder-3-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-3-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-3-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-3-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-4-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-3-FeedForward-Norm[0][0]
#                                                                  Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-4-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-4-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-4-MultiHeadSelfAttention-
#                                                                  Encoder-4-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-4-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-4-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-4-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-5-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-4-FeedForward-Norm[0][0]
#                                                                  Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-5-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-5-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-5-MultiHeadSelfAttention-
#                                                                  Encoder-5-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-5-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-5-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-5-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-6-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-5-FeedForward-Norm[0][0]
#                                                                  Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-6-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-6-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-6-MultiHeadSelfAttention-
#                                                                  Encoder-6-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-6-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-6-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-6-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-7-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-6-FeedForward-Norm[0][0]
#                                                                  Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-7-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-7-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-7-MultiHeadSelfAttention-
#                                                                  Encoder-7-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-7-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-7-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-7-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-8-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-7-FeedForward-Norm[0][0]
#                                                                  Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-8-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-8-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-8-MultiHeadSelfAttention-
#                                                                  Encoder-8-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-8-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-8-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 30, 768)      2362368     Encoder-8-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-9-MultiHeadSelfAttention[
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 30, 768)      0           Encoder-8-FeedForward-Norm[0][0]
#                                                                  Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-MultiHeadSelfAttentio (None, 30, 768)      1536        Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-FeedForward (FeedForw (None, 30, 768)      4722432     Encoder-9-MultiHeadSelfAttention-
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Dropout ( (None, 30, 768)      0           Encoder-9-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Add (Add) (None, 30, 768)      0           Encoder-9-MultiHeadSelfAttention-
#                                                                  Encoder-9-FeedForward-Dropout[0][
# __________________________________________________________________________________________________
# Encoder-9-FeedForward-Norm (Lay (None, 30, 768)      1536        Encoder-9-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 30, 768)      2362368     Encoder-9-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-9-FeedForward-Norm[0][0]
#                                                                  Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-MultiHeadSelfAttenti (None, 30, 768)      1536        Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-FeedForward (FeedFor (None, 30, 768)      4722432     Encoder-10-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Dropout  (None, 30, 768)      0           Encoder-10-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Add (Add (None, 30, 768)      0           Encoder-10-MultiHeadSelfAttention
#                                                                  Encoder-10-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-10-FeedForward-Norm (La (None, 30, 768)      1536        Encoder-10-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 30, 768)      2362368     Encoder-10-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-10-FeedForward-Norm[0][0]
#                                                                  Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-MultiHeadSelfAttenti (None, 30, 768)      1536        Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-FeedForward (FeedFor (None, 30, 768)      4722432     Encoder-11-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Dropout  (None, 30, 768)      0           Encoder-11-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Add (Add (None, 30, 768)      0           Encoder-11-MultiHeadSelfAttention
#                                                                  Encoder-11-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-11-FeedForward-Norm (La (None, 30, 768)      1536        Encoder-11-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 30, 768)      2362368     Encoder-11-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 30, 768)      0           Encoder-11-FeedForward-Norm[0][0]
#                                                                  Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-MultiHeadSelfAttenti (None, 30, 768)      1536        Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-FeedForward (FeedFor (None, 30, 768)      4722432     Encoder-12-MultiHeadSelfAttention
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Dropout  (None, 30, 768)      0           Encoder-12-FeedForward[0][0]
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Add (Add (None, 30, 768)      0           Encoder-12-MultiHeadSelfAttention
#                                                                  Encoder-12-FeedForward-Dropout[0]
# __________________________________________________________________________________________________
# Encoder-12-FeedForward-Norm (La (None, 30, 768)      1536        Encoder-12-FeedForward-Add[0][0]
# __________________________________________________________________________________________________
# Encoder-Output (Concatenate)    (None, 30, 3072)     0           Encoder-9-FeedForward-Norm[0][0]
#                                                                  Encoder-10-FeedForward-Norm[0][0]
#                                                                  Encoder-11-FeedForward-Norm[0][0]
#                                                                  Encoder-12-FeedForward-Norm[0][0]
# __________________________________________________________________________________________________
# input_feature1 (InputLayer)     (None, 30)           0
# __________________________________________________________________________________________________
# input_feature2 (InputLayer)     (None, 30)           0
# __________________________________________________________________________________________________
# input_feature3 (InputLayer)     (None, 30)           0
# __________________________________________________________________________________________________
# non_masking_layer (NonMaskingLa (None, 30, 3072)     0           Encoder-Output[0][0]
# __________________________________________________________________________________________________
# layer_embedding_feature1 (Embed (None, 30, 8000)     8008000     input_feature1[0][0]
# __________________________________________________________________________________________________
# layer_embedding_feature2 (Embed (None, 30, 8000)     8008000     input_feature2[0][0]
# __________________________________________________________________________________________________
# layer_embedding_feature3 (Embed (None, 30, 8000)     8008000     input_feature3[0][0]
# __________________________________________________________________________________________________
# layer_concatenate (Concatenate) (None, 30, 27072)    0           non_masking_layer[0][0]
#                                                                  layer_embedding_feature1[0][0]
#                                                                  layer_embedding_feature2[0][0]
#                                                                  layer_embedding_feature3[0][0]
# __________________________________________________________________________________________________
# layer_blstm (Bidirectional)     (None, 30, 256)      27853824    layer_concatenate[0][0]
# __________________________________________________________________________________________________
# layer_dropout (Dropout)         (None, 30, 256)      0           layer_blstm[0][0]
# __________________________________________________________________________________________________
# layer_time_distributed (TimeDis (None, 30, 3)        771         layer_dropout[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 30, 3)        0           layer_time_distributed[0][0]
# ==================================================================================================
# Total params: 160,400,067
# Trainable params: 51,878,595
# Non-trainable params: 108,521,472
# __________________________________________________________________________________________________
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-723f2f2ea7fe> in <module>
#       5
#       6
# ----> 7 model.fit(train_x, train_y, dev_x, dev_y)
#       8
#       9 # Evaluate the model
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/tasks/base_model.py in fit(self, x_train, y_train, x_validate, y_validate, batch_size, epochs, callbacks, fit_kwargs)
#     293                                                validation_steps=validation_steps,
#     294                                                callbacks=callbacks,
# --> 295                                                **fit_kwargs)
#     296
#     297     def fit_without_generator(self,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424         use_multiprocessing=use_multiprocessing,
#    1425         shuffle=shuffle,
# -> 1426         initial_epoch=initial_epoch)
#    1427
#    1428   def evaluate_generator(self,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     175
#     176     for step in range(steps_per_epoch):
# --> 177       batch_data = _get_next_batch(output_generator, mode)
#     178       if batch_data is None:
#     179         callbacks.model.stop_training = True
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in _get_next_batch(output_generator, mode)
#     256   """Retrieves the next batch of input data."""
#     257   try:
# --> 258     generator_output = next(output_generator)
#     259   except (errors.OutOfRangeError, StopIteration):
#     260     # Returning `None` will trigger looping to stop.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     765             'Keras requires a thread-safe generator when '
#     766             '`use_multiprocessing=False, workers > 1`. ')
# --> 767       six.reraise(*sys.exc_info())
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/utils/data_utils.py in get(self)
#     741     try:
#     742       while self.is_running():
# --> 743         inputs = self.queue.get(block=True).get()
#     744         self.queue.task_done()
#     745         if inputs is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/keras/utils/data_utils.py in next_sample(uid)
#     678       The next value of generator `uid`.
#     679   """
# --> 680   return six.next(_SHARED_SEQUENCES[uid])
#     681
#     682
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/tasks/base_model.py in get_data_generator(self, x_data, y_data, batch_size, shuffle)
#     231                                                             target_index)
#     232                 y_tensor = self.embedding.process_y_dataset(y_data,
# --> 233                                                             target_index)
#     234                 yield (x_tensor, y_tensor)
#     235
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/embeddings/stacked_embedding.py in process_y_dataset(self, data, subset)
#     112                           data: List[List[str]],
#     113                           subset: Optional[List[int]] = None) -> np.ndarray:
# --> 114         return self.embeddings[0].process_y_dataset(data, subset)
#     115
#     116
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/embeddings/base_embedding.py in process_y_dataset(self, data, subset)
#     209             vectorized feature tensor
#     210         """
# --> 211         return self.processor.process_y_dataset(data, self.sequence_length, subset)
#     212
#     213     def reverse_numerize_label_sequences(self,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/processors/labeling_processor.py in process_y_dataset(self, data, max_len, subset)
#      75         else:
#      76             target = data[:]
# ---> 77         numerized_samples = self.numerize_label_sequences(target)
#      78         padded_seq = pad_sequences(
#      79             numerized_samples, max_len, padding='post', truncating='post')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/processors/labeling_processor.py in numerize_label_sequences(self, sequences)
#      97             if self.add_bos_eos:
#      98                 seq = [self.token_pad] + seq + [self.token_pad]
# ---> 99             result.append([self.label2idx[label] for label in seq])
#     100         return result
#     101
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/kashgari/processors/labeling_processor.py in <listcomp>(.0)
#      97             if self.add_bos_eos:
#      98                 seq = [self.token_pad] + seq + [self.token_pad]
# ---> 99             result.append([self.label2idx[label] for label in seq])
#     100         return result
#     101
#
# KeyError: 1
