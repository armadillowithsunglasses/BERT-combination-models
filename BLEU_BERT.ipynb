# %%
from time import time
import pandas as pd
import numpy as np
from gensim.models import KeyedVectors
import re
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

import itertools
import datetime

from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.layers import Input, Embedding, LSTM, Lambda
import keras.backend as K
from keras.optimizers import Adadelta
from keras.callbacks import ModelCheckpoint
from bert_serving.client import BertClient
# Out:
# Using TensorFlow backend.

# %%
bc = BertClient()
test=bc.encode(['First do it ||| then do it right'])
print(test)
data_meta = np.array((len(test), 768))
nlp_input = Input(shape=(60,), name='nlp_input')
x = concatenate([nlp_out, meta_input])
#requires a Bert server to be run please check https://github.com/hanxiao/bert-as-service#what-is-it
# Out:
# [[-5.04763722e-02 -4.87895310e-02 -4.83554065e-01 -3.42728883e-01
#   -1.14914678e-01  1.62609816e-01  2.15244770e-01  3.63935769e-01
#    3.03730786e-01 -4.82231468e-01 -4.92257215e-02 -1.86317861e-01
#   -1.67600513e-01 -2.55926222e-01 -9.69771028e-01  6.47908509e-01
#   -3.97496045e-01 -2.62127548e-01  3.59476879e-02  2.64713436e-01
#   -2.11805508e-01  3.13155830e-01 -4.49802876e-01 -7.70862550e-02
#    2.49953300e-01 -3.49985540e-01  1.01401851e-01 -4.91841704e-01
#   -1.98673695e-01  2.33608961e-01  3.21058810e-01 -2.94979453e-01
#   -1.78063601e-01 -1.19715571e-01  1.49329379e-01  4.04063702e-01
#    4.29855198e-01  7.30635673e-02 -4.05314118e-01  6.16669953e-02
#   -5.23368716e-01 -3.88182312e-01 -2.52037108e-01 -4.18566853e-01
#   -1.22309744e-01 -3.84358525e-01 -6.28781468e-02  7.63056800e-02
#    3.56706455e-02 -5.75758040e-01 -8.97076726e-01  7.11736456e-02
#   -2.45786637e-01 -5.80639616e-02 -2.74653584e-01  3.07207763e-01
# ...

# %%
# File paths
TRAIN_CSV = '/Users/ishitagupta/Desktop/train.csv'  
DEV_CSV = '/Users/ishitagupta/Desktop/test.csv'
MODEL_SAVING_DIR = '/Users/ishitagupta/Bleu_bert'

# %%
# Load training and test set
train_df = pd.read_csv(TRAIN_CSV)
dev_df = pd.read_csv(DEV_CSV)
sentence_cols = ['sentence1', 'sentence2']

# %%
#defining the training and validation/dev set data
X_train = train_df[sentence_cols]
Y_train = train_df['machine_text']

X_validation = dev_df[sentence_cols]
Y_validation = dev_df['machine_text']

# Split into left and right for the 2 LSTM's 
X_train = {'left': X_train.sentence1, 'right': X_train.sentence2}
X_validation = {'left': X_validation.sentence1, 'right': X_validation.sentence2}

# Convert labels to their numpy representations
Y_train = Y_train.values
Y_validation = Y_validation.values

# Make sure everything is ok
assert X_train['left'].shape == X_train['right'].shape
assert len(X_train['left']) == len(Y_train)

# %%
data_meta = np.array((len(data_nlp), 10))

# %%
#model 
nlp_input_1 = Input(shape=(seq_length,), name='sentence1')  
nlp_input_2 = Input(shape=(seq_length,), name='sentence2')  

test=bc.encode(['First do it ||| then do it right'])

data_meta = np.array((len(data_nlp), 10))

# %%
nlp_input = Input(shape=(seq_length,), name='nlp_input')
meta_input = Input(shape=(10,), name='meta_input')
emb = Embedding(output_dim=embedding_size, input_dim=100, input_length=seq_length)(nlp_input)
nlp_out = Bidirectional(LSTM(128, dropout=0.3, recurrent_dropout=0.3, kernel_regularizer=regularizers.l2(0.01)))(emb)
x = concatenate([nlp_out, meta_input])
x = Dense(classifier_neurons, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(inputs=[nlp_input , meta_input], outputs=[x])
